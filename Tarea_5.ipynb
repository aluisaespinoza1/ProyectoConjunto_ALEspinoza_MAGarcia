# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Ana Luisa Espinoza López, Mario Alberto García Roman.
#
# **Fecha:** 28 de septiembre del 2023.
#
# **Expediente** : 734753.
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link Github**: https://github.com/aluisaespinoza1/ProyectoConjunto_ALEspinoza_MAGarcia
#
# # Tarea 5: Clase 10

# %% [markdown]
# ## Enunciado de tarea
#
# # Tarea
# Partiendo que se desea generar variables aleatorias para la siguiente función de densidad
# $$f(x)=30(x^2-2x^3+x^4)$$
# Responda los siguientes literales:
# 1. Usar como función que mayora a $f(x)$ a $t(x)=a \sin(\pi x)$ donde a es el máximo de la función $f(x)$ y graficarlas en una misma gráfica, para validar que en realidad si cumple la condición $t(x)\geq f(x)$.
# 2. Encontrar la función de densidad $g(x)$ según lo visto en clase. Reportar todos los cálculos realizados para encontrar dicha función usando Markdown (Latex).
# 3. Usar la función encontrada en el punto 2 y utilizar el método de la transformada inversa visto en la clase 9, para generar variables aleatorias que sigan la distribución $g(x)$. **Nota:** Recuerde que el método de la transformada inversa funciona con la distribución de probabilidad acumulada y no con su densidad. Nuevamente similar al punto anterior reportar todos los cálculos usando Markdown (Latex).
# 4. Según el punto 3, generar 10000 puntos aleatorios que sigan la distribución $g(x)$ y comparar con su histograma para validar que los puntos generados siguen la distribución deseada. El resultado debe ser como sigue:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. Genere 500 puntos aleatorios usando el método de aceptación y rechazo y las funciones $f(x)$ y $t(x)$ para validar que todos los cálculos anteriores están correctamente realizados. El resultado debe de ser como sigue:
# ![image.png](attachment:image.png)
#
# 6. Comparar el porcentaje de puntos de aceptación cuando se usa $t(x)$ constante y $t(x)$ un pulso senoidal. Concluir

# %% [markdown]
# 7. Genere una variable aleatoria $X$ a partir de la siguiente PDF
# $$f(x)=20x(1-x)^3$$
# usando el método de aceptación y rechazo
#
# 8. Demostrar la validez de la siguiente ecuación
# $$p_{i+1}=\frac{n-i}{i+1}\frac{p}{1-p} p_i$$
#
# 9. Seguir un procedimiento similar al mostrado cuando se generó una distribución binomial, pero en esta caso genere un código que genere variables aletorias Poisson cuya función de distribución de probabilidad esta dada por:
# $$P(k,\lambda)=\frac{e^{-\lambda}(\lambda)^k}{k!}$$
#
#
# Demuestre matemáticamente que
#  $$P(k+1)=\frac{\lambda}{k+1}P(k)$$
#  y a partir de esta relación genere variables aletorias que distribuyen poisson usando el método de la transformada inversa.

# %% [markdown]
# ### Ejercicio 1:
#
# Partiendo que se desea generar variables aleatorias para la siguiente función de densidad
# $$f(x)=30(x^2-2x^3+x^4)$$
# Responda los siguientes literales:
# 1. Usar como función que mayora a $f(x)$ a $t(x)=a \sin(\pi x)$ donde a es el máximo de la función $f(x)$ y graficarlas en una misma gráfica, para validar que en realidad si cumple la condición $t(x)\geq f(x)$.

# %% [markdown]
# Código de solución Ana Luisa

# %%
# Librería de optimización 
from scipy import optimize
import random
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib notebook
# %matplotlib inline

# %%
f = lambda x: 30 * (x**2 -2 * x**3 + x**4)
# Máximo de la función f
a = f(optimize.fmin(lambda x:-f(x), 0, disp=False))
t = lambda x: a*np.sin(np.pi*x)

x = np.arange(0, 1, 0.01)

print('El máximo de f(x) es:',a)

plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()
# Out:
# El máximo de f(x) es: [1.875]

# %% [markdown]
# Código de solución Mario

# %%
# Código de solución estudiante 2
f = lambda x: 30 * (x**2 -2 * x**3 + x**4)
# Máximo de la función f
a = f(optimize.fmin(lambda x:-f(x), 0, disp=False))
t = lambda x: a*np.sin(np.pi*x)

x = np.arange(0, 1, 0.01)

print('El máximo de f(x) es:',a)
# Out:
# El máximo de f(x) es: [1.875]

# %%
plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()

# %% [markdown]
# ### Ejercicio 2:
# 2. Encontrar la función de densidad $g(x)$ según lo visto en clase. Reportar todos los cálculos realizados para encontrar dicha función usando Markdown (Latex).

# %% [markdown]
# Código de solución Ana Luisa

# %% [markdown]
# La función $g(x)$ se define como: $$g(x) = \frac{t(x)}{c}$$
#
# El valor de $c$ es una constante resultante de la siguiente expresión: $$c=\int_{-\infty}^{\infty}t(x) dx $$
#
# En este caso, la integral de la función $t(x) = a \sin(\pi x)$ tiene límites definidos donde $a = 0$ y $b = 1$ por lo que:
#  $$c=\int_{0}^{1} a \sin(\pi x)  dx = \frac{2a}{\pi} $$
#
# Entonces, la función $g(x)$ es: $$g(x) = \frac{a \sin(\pi x)}{\frac{2a}{\pi}} = \frac{a \sin(\pi x) \pi}{2a} = \frac{\pi \sin(\pi x)}{2}$$

# %% [markdown]
# Código de solución Mario

# %% [markdown]
# La función de densidad g(x)g(x) para una variable aleatoria continua X que sigue una distribución definida por:
# $$g(x) = \frac{a sin(\pi x)}{\frac{2a}{\pi}}$$
#
# Primero, vamos a simplificar la expresión utilizando la constante c:
# $$ c = \frac{2a}{\pi}$$
#
# Ahora, reemplazamos c en la expresión para g(x):
# $$ g(x) = \frac{a sin(\pi x)}{c}$$
#
# $$ g(x) = \frac{a sin(\pi x)}{\frac{2a}{\pi}}$$
#
# $$ g(x) = \frac{a sin(\pi x)\pi}{2a}$$
#
# $$ g(x) = \frac{\pi sin(\pi x)}{2}$$
#
# Entonces, la función de densidad g(x) para esta variable aleatoria continua X es:
# $$ g(x) = \frac{\pi sin(\pi x)}{2}$$
#
# Esta es la función de densidad de probabilidad para X en el intervalo [0,1], donde X sigue una distribución definida por t(x)=a sin(πx).

# %% [markdown]
# ### Ejercicio 3:
# 3. Usar la función encontrada en el punto 2 y utilizar el método de la transformada inversa visto en la clase 9, para generar variables aleatorias que sigan la distribución $g(x)$. **Nota:** Recuerde que el método de la transformada inversa funciona con la distribución de probabilidad acumulada y no con su densidad. Nuevamente similar al punto anterior reportar todos los cálculos usando Markdown (Latex).

# %% [markdown]
# Código de solución Ana Luisa

# %% [markdown]
# La función $g(x)$ es una densidad de probabilidad, para aplicar el método de la transformada inversa se necesita la distribución de probabilidad acumulada $G(x)$ que se calcula de la siguiente manera:
# $$ G(x) =\int_{0}^{x} g(x)  dx $$
#
# La distribución de probabilidad acumulada para $g(x)$ es:
#
# $$ G(x) = \frac{\pi}{2} \int_{0}^{x} sin (\pi x) = \frac{1- cos(\pi x)}{2}$$
#
# **Método de la transformada inversa**:
# $$ \frac{1- cos(\pi x)}{2} = U $$
#
# Despejando $x$:
# $$ x = \frac{cos^{-1}(1 - 2U)}{\pi}$$

# %% [markdown]
# Código de solución Mario

# %% [markdown]
# Dado que hemos obtenido la distribución acumulada
# $$ g(x) = \frac{1 - cos(\pi x)}{2}$$
# ,vamos a encontrar la función de densidad g(x) utilizando el método de la transformada inversa.
#
# Para ello, primero resolvemos la ecuación:
# $$\frac{1 - cos(\pi x)}{2} = U$$
# Donde U es una variable aleatoria uniforme en el intervalo [0,1].
#
# Despejando x:
# $$ x = \frac{cos^{-1}(1 - 2U)}{\pi}$$
#
# Ahora, hemos encontrado la relación entre x y U, lo que significa que x sigue la distribución de probabilidad g(x) deseada.
#
# Por lo tanto, la función de densidad de probabilidad g(x) está definida como:
# $$ g(x) = \frac{d}{dx}\frac({1 - cos(\pi x)}{2})$$
#
# Calculemos su derivada:
# $$ g(x) = \frac{d}{dx}(\frac{1}{2} - \frac{cos(\pi x)}{2}) = \frac{1}{2} * \frac{d}{dx}(1)-\frac{1}{2}*\frac{d}{dx}(cos(\pi x))$$
#
# Dado que la derivada de 1 es 0, nos queda:
# $$-\frac{1}{2}*\frac{d}{dx}(cos(\pi x)) = \frac{\pi}{2}sin(\pi x)$$
#
# Entonces, la función de densidad de probabilidad g(x) es:
# $$ g(x) = \frac{\pi}{2}sin(\pi x)$$

# %% [markdown]
# ### Ejercicio 4:
# 4. Según el punto 3, generar 10000 puntos aleatorios que sigan la distribución $g(x)$ y comparar con su histograma para validar que los puntos generados siguen la distribución deseada. El resultado debe ser como sigue:

# %% [markdown]
# Código de solución Ana Luisa

# %%
def distribucion(N:'num de puntos aleatorios',
                 gx:'funcion g(x)',G_inv:'inversa de G'):
    U = np.random.rand(N)
    p_a = G_inv(U) #puntos aleatorios
    x = np.arange(0, 1, 0.01)
    g = gx(x)
    plt.hist(p_a, bins=50, density = True, label='$G^{-1}$',)
    plt.plot(x,g, label='$g(x)$')
    plt.legend()
    plt.show()

# %%
N = 10000
g = lambda x: np.sin(np.pi * x)*(np.pi / 2)
G_inv = lambda U: np.arccos(1 - 2*U) * (1 / np.pi)

distribucion(N,g,G_inv)

# %% [markdown]
# Código de solución Mario

# %%
# Código de solución estudiante 2
def distribucion(N, gx, G_inv):
    U = np.random.rand(N)
    p_a = G_inv(U) # Puntos aleatorios
    x = np.linspace(0, 1, 1000)  # Incrementamos la cantidad de puntos en x para suavizar la gráfica
    g = gx(x)
    
    plt.hist(p_a, bins=50, density=True, label='$G^{-1}$')
    plt.plot(x, g, label='$g(x)$')
    plt.legend()
    plt.xlabel('$x$')
    plt.ylabel('Densidad de Probabilidad')
    plt.show()

N = 10000
g = lambda x: np.sin(np.pi * x) * (np.pi / 2)
G_inv = lambda U: np.arccos(1 - 2 * U) / np.pi  # Corregimos el cálculo de la inversa

distribucion(N, g, G_inv)

# %% [markdown]
# ### Ejercicio 5:
# 5. Genere 500 puntos aleatorios usando el método de aceptación y rechazo y las funciones $f(x)$ y $t(x)$ para validar que todos los cálculos anteriores están correctamente realizados. El resultado debe de ser como sigue:
# ![image.png](attachment:image.png)

# %% [markdown]
# Código de solución Ana Luisa

# %%
def Acep_rechazo(N: 'número de puntos',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
    R2 = np.random.rand(N)
    R1 = np.random.rand(N)
    f_x = f(R1)
    t_x = t(R1)
    condition = R2*t_x <=f_x
    [plt.plot(R1[i],R2[i]*t_x[i],'ob') if condition[i] else plt.plot(R1[i],R2[i]*t_x[i],'o') \
         for i in range(len(R1))]
                
    plt.show()

# %%
N = 500
f = lambda x: 30 * (x**2 -2 * x**3 + x**4)
# Máximo de la función f
a = f(optimize.fmin(lambda x:-f(x), 0, disp=False))
t = lambda x: a*np.sin(np.pi*x)

plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()
Acep_rechazo(N,f,t)

# %% [markdown]
# Código de solución Mario

# %%
# Código de solución estudiante 2
def Acep_rechazo(N, f, t):
    accepted_x = []
    accepted_y = []
    rejected_x = []
    rejected_y = []

    x = np.linspace(0, 1, 1000)  # Espacio de muestra para trazar las funciones
    f_x = f(x)
    t_x = t(x)

    for _ in range(N):
        R1 = np.random.rand()
        R2 = np.random.rand()
        if R2 * t_x[int(R1 * 1000)] <= f_x[int(R1 * 1000)]:
            accepted_x.append(R1)
            accepted_y.append(R2 * t_x[int(R1 * 1000)])
        else:
            rejected_x.append(R1)
            rejected_y.append(R2 * t_x[int(R1 * 1000)])

    plt.plot(accepted_x, accepted_y, 'ob', label='Aceptados')
    plt.plot(rejected_x, rejected_y, 'o', label='Rechazados')
    plt.plot(x, f_x, label='f(x)')
    plt.plot(x, t_x, label='t(x)')
    plt.legend()
    plt.show()

# %%
N = 500
f = lambda x: 30 * (x**2 - 2 * x**3 + x**4)

# Máximo de la función f
a = f(optimize.fmin(lambda x: -f(x), 0, disp=False))

t = lambda x: a * np.sin(np.pi * x)

Acep_rechazo(N, f, t)

# %% [markdown]
# ### Ejercicio 6:
# 6. Comparar el porcentaje de puntos de aceptación cuando se usa $t(x)$ constante y $t(x)$ un pulso senoidal. Concluir

# %% [markdown]
# Código de solución Ana Luisa

# %%
def porcentaje_A_R(N:'número de puntos',
    f:'función objetivo a generar',
    t:'función que mayora a f'):
    
    R2 = np.random.rand(N)
    R1 = np.random.rand(N)
    f_x = f(R1)
    t_x = t(R1)
    condition = R2*t_x <=f_x
    acept = [R1[i] for i in range(len(R1)) if condition[i]]
    P = len(acept)/N
    return P

# %%
N = 500
f = lambda x: 30 * (x**2 -2 * x**3 + x**4)
a = f(optimize.fmin(lambda x:-f(x), 0, disp=False))

t_sen = lambda x: a*np.sin(np.pi*x)
t_c = lambda x: a * np.ones(len(x))

p_senoidal = porcentaje_A_R(N,f,t_sen)
constante = porcentaje_A_R(N,f,t_c)

# %%
print(f"El porcentaje de puntos de aceptación usando un pulso senoidal como t(x) es de: {p_senoidal*100}%")
print(f"El porcentaje de puntos de aceptación usando una constante como t(x) es de: {constante*100}%")
# Out:
# El porcentaje de puntos de aceptación usando un pulso senoidal como t(x) es de: 70.6%
# El porcentaje de puntos de aceptación usando una constante como t(x) es de: 57.4%

# %% [markdown]
# **Conclusión:**
# El pulso senoidal aproxima mejor el área de $f(x)$ que una constante y se puede observar con los porcentajes de aceptación que con $t(x)$ como pulso senoidal se aceptan aproximadamente 13.2% puntos más.

# %% [markdown]
# Código de solución Mario

# %%
# Código de solución estudiante 2
def Acep_rechazo(N, f, t):
    accepted_x = []
    accepted_y = []

    x = np.linspace(0, 1, 1000)  # Espacio de muestra para trazar las funciones
    f_x = f(x)
    t_x = t(x)

    for _ in range(N):
        R1 = np.random.rand()
        R2 = np.random.rand()
        if R2 * t_x[int(R1 * 1000)] <= f_x[int(R1 * 1000)]:
            accepted_x.append(R1)
            accepted_y.append(R2 * t_x[int(R1 * 1000)])

    return accepted_x, accepted_y

# %%
N = 500
f = lambda x: 30 * (x**2 - 2 * x**3 + x**4)

# Máximo de la función f
a = f(optimize.fmin(lambda x: -f(x), 0, disp=False))

# Función t(x) constante
t_constante = lambda x: a * np.ones_like(x)

# Función t(x) pulso senoidal
t_senoidal = lambda x: a * np.sin(np.pi * x)

# Realizar el método de aceptación-rechazo para t(x) constante
accepted_x_constante, _ = Acep_rechazo(N, f, t_constante)

# Realizar el método de aceptación-rechazo para t(x) pulso senoidal
accepted_x_senoidal, _ = Acep_rechazo(N, f, t_senoidal)

# Calcular el porcentaje de puntos de aceptación en ambos casos
porcentaje_aceptacion_constante = len(accepted_x_constante) / N * 100
porcentaje_aceptacion_senoidal = len(accepted_x_senoidal) / N * 100

# %%
print(f"Porcentaje de aceptación con t(x) constante: {porcentaje_aceptacion_constante}%")
print(f"Porcentaje de aceptación con t(x) senoidal: {porcentaje_aceptacion_senoidal}%")
# Out:
# Porcentaje de aceptación con t(x) constante: 50.6%
# Porcentaje de aceptación con t(x) senoidal: 72.2%

# %% [markdown]
# ### Ejercicio 7:
# 7. Genere una variable aleatoria $X$ a partir de la siguiente PDF
# $$f(x)=20x(1-x)^3$$
# usando el método de aceptación y rechazo

# %% [markdown]
# Código de solución Ana Luisa

# %%
def Acep_rechazo2(N: 'número de puntos',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
    R2 = np.random.rand(N)
    R1 = np.random.rand(N)
    f_x = f(R1)
    t_x = t(R1)
    condition = R2*t_x <=f_x
    [plt.plot(R1[i],R2[i]*t_x[i],'ob') if condition[i] else plt.plot(R1[i],R2[i]*t_x[i],'o') \
         for i in range(len(R1))]
                
    plt.show()
    
    pa = [R1[i] for i in range(len(R1)) if condition[i]]
    
    return pa

# %%
N = 1500
f = lambda x: 20*x * (1-x)**3
max_f = f(optimize.fmin(lambda x:-f(x),0,disp=False))
t = lambda x: max_f*np.ones(len(x))

plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()

var_aleatoria = Acep_rechazo2(N, f, t)

# %%
plt.plot(x,f(x),label='f(x)')
plt.legend()
plt.hist(var_aleatoria, bins=15, density=True);

# %% [markdown]
# Código de solución Mario

# %%
# Código de solución estudiante 2
# Función de densidad de probabilidad f(x)
f = lambda x: 20 * x * (1 - x)**3

# Encontrar M, una cota superior para f(x)
x = np.linspace(0, 1, 1000)
M = max(f(x))

# Generar variables aleatorias usando el método de aceptación-rechazo
N = 10000  # Número de muestras a generar
samples = []
accepted = 0

while accepted < N:
    X1 = np.random.rand()
    X2 = np.random.rand() * M
    
    if X2 <= f(X1):
        samples.append(X1)
        accepted += 1

# %%
# Visualizar el histograma de las muestras generadas
plt.hist(samples, bins=50, density=True, alpha=0.6, label='Muestras generadas')
plt.plot(x, f(x), 'r', label='f(x)')
plt.legend()
plt.xlabel('X')
plt.ylabel('Densidad de probabilidad')
plt.title('Generación de muestras con el método de aceptación-rechazo')
plt.show()

# %% [markdown]
# ### Ejercicio 8:
# 8. Demostrar la validez de la siguiente ecuación
# $$p_{i+1}=\frac{n-i}{i+1}\frac{p}{1-p} p_i$$

# %% [markdown]
# Código de solución Ana Luisa

# %% [markdown]
# Tomando en cuenta las siguientes propiedades de los factoriales:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Partiendo de la expresión:
# $$ p_i=P(X=i)=\frac{n!}{i!(n-i)!}p^i(1-p)^{n-i} $$
#
# Sustituyendo en la expresión $i$ por $i+1$ la ecuación queda de la siguiente forma:
#
# $$ p_{i+1} = \frac{n!}{(i+1)!(n-(i+1))!}p^{i+1}(1-p)^{n-(i+1)} $$
#
# Dividiendo este término entre el anterior:
#
# $$ p_{i+1} = \frac{\frac{n!}{(i+1)!(n-(i+1))!}p^{i+1}(1-p)^{n-(i+1)}}{\frac{n!}{i!(n-i)!}p^i(1-p)^{n-i}} = \frac{(n-i)p}{(1+i)(1-p)}p_i $$
#
# Entonces la ecuación queda:
# $$ p_{i+1} = \frac{n-i}{i+1}\frac{p}{1-p} p_i$$

# %% [markdown]
# Código de solución Mario

# %% [markdown]
# La ecuación se puede expresar de la siguiente manera:
# $$ p_{i+1} = \frac{n-i}{i+1}*\frac{p}{1-p}*p_i$$
# Ahora, vamos a demostrar su validez usando el principio fundamental de la probabilidad y el concepto de probabilidad condicional.
#
# Comencemos con el lado izquierdo de la ecuación:
# $$p_{i+1} = P(tener i+1  exitos en n intentos)$$
#
# Ahora, consideremos el lado derecho de la ecuación:
# $$\frac{n-i}{i+1}*\frac{p}{1-p}*p_i$$
# Multiplicamos los términos juntos:
# $$\frac{n-i}{i+1}*\frac{p}{1-p}*p_i = \frac{(n-i)*p}{(1+i)*(1-p)}*p_i$$
# Observamos que
# $$\frac{(n-i)*p}{(1+i)*(1-p)}$$
# es simplemente el coeficiente binomial que describe la probabilidad de tener i+1 éxitos en n intentos:
# $$\frac{n-i}{i+1}*\frac{p}{1-p} = $$
# Entonces, podemos escribir:
# $$\frac{n-i}{i+1}*\frac{p}{1-p}*p_i = *p_i$$
# Dado que
# es igua a p_{i+1}(como se demostró anteriormente), hemos demostrado que:
# $$ p_{i+1} = \frac{n-i}{i+1}*\frac{p}{1-p}*$
# \left(
# \begin{array}{ll}
# n
# 1+i
# \end{array}
# \right)
# $p_i$$
# Por lo tanto, la ecuación dada es válida y representa la probabilidad de tener i+1 éxitos en n intentos dados los parámetros n, p, y i.

# %% [markdown]
# ### Ejercicio 9:
# 9. Seguir un procedimiento similar al mostrado cuando se generó una distribución binomial, pero en esta caso genere un código que genere variables aletorias Poisson cuya función de distribución de probabilidad esta dada por:
# $$P(k,\lambda)=\frac{e^{-\lambda}(\lambda)^k}{k!}$$
#
#
# Demuestre matemáticamente que
#  $$P(k+1)=\frac{\lambda}{k+1}P(k)$$
#  y a partir de esta relación genere variables aletorias que distribuyen poisson usando el método de la transformada inversa.

# %% [markdown]
# Código de solución Ana Luisa

# %% [markdown]
# Partiendo de la ecuación $P(k,\lambda)=\frac{e^{-\lambda}(\lambda)^k}{k!}$, suponiendo que $\lambda$ es constante tenemos:
#
# $$ P(k)=\frac{e^{-\lambda}(\lambda)^k}{k!} $$
#
# Sustituyendo $k$ por $k+1$ la ecuación queda:
#
# $$P(k+1)=\frac{e^{-\lambda}(\lambda)^{k+1}}{(k+1)!}$$
#
# Dividiendo entre el término anterior:
#
# $$ P(k+1)= \frac{\frac{e^{-\lambda}(\lambda)^{k+1}}{(k+1)!}}{\frac{e^{-\lambda}(\lambda)^k}{k!}} $$
# $$ P(k+1)= \frac{e^{-\lambda}(\lambda)^{k}\lambda}{(k+1)k!} = \frac{e^{-\lambda}(\lambda)^k}{k!}\frac{\lambda}{k+1}$$
#
# En la ecuación anterior se puede observar que se encuentra el término de $P(K)$, entonces sustituyendo:
#
#  $$P(k+1)=\frac{\lambda}{k+1}P(k)$$

# %%
def Poisson(k,l):
    global pr
    pr = np.zeros(k)
    pr[0] = np.exp(-l)
    def Pr(i):
        global pr
        pr[i+1]=l/(i+1)*pr[i]
        
    # Lleno el vector Pr usando compresión de listas
    [Pr(i) for i in range(k-1)]
    return np.cumsum(pr)

# %%
N = 10000
k, lam = 17, 6
poisson = Poisson(k,lam) #prob acumulada distr Poisson


u = np.random.rand(N)

distribucion = list(map(lambda j:sum(1 for i in poisson if i<u[j]),range(N)))


plt.figure(figsize=[10,4])
y, x = np.histogram(distribucion, bins=len(set(distribucion)), density=True) 
plt.bar(x[1:], y, label='Distribución de Poisson')
plt.legend()
plt.show()

# %% [markdown]
# Código de solución Mario

# %%
# Código de solución estudiante 2
def Poisson(k,l):
    global pr
    pr = np.zeros(k)
    pr[0] = np.exp(-l)
    def Pr(i):
        global pr
        pr[i+1]=l/(i+1)*pr[i]
        
    # Lleno el vector Pr usando compresión de listas
    [Pr(i) for i in range(k-1)]
    return np.cumsum(pr)

# %%
N = 10000
k, lam = 17, 6
poisson = Poisson(k,lam) #prob acumulada distr Poisson


u = np.random.rand(N)

distribucion = list(map(lambda j:sum(1 for i in poisson if i<u[j]),range(N)))


plt.figure(figsize=[10,4])
y, x = np.histogram(distribucion, bins=len(set(distribucion)), density=True) 
plt.bar(x[1:], y, label='Distribución de Poisson')
plt.legend()
plt.show()
